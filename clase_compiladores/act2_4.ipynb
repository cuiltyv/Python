# %% [markdown]
# # Clasificador Bayesiano Inegnuo
#
# El clasificador bayesiano es un clasificador el se basa en el teorema de bayes, se basa en el principio de que la probabilidad de un evento se actualiza basada en nueva informacion. Por medio de la siguiente formula: La probabilidad P(A∣B), se puede calcular a partir de P(B|A) y las probabilidades marginales P(A) y P(B)

# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
train = pd.read_csv("mnist/mnist_train.csv")
test = pd.read_csv("mnist/mnist_test.csv")

X_train = train.drop("label", axis=1)
y_train = train["label"]

X_test = test.drop("label", axis=1)
y_test = test["label"]

# %%
model_bi = GaussianNB()
model_bi.fit(X_train, y_train)

y_pred = model_bi.predict(X_test)

# %%
#Matriz de confusion clasificador bayesiano
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 870,    0,    3,    5,    2,    5,   31,    1,   35,   28],
#        [   0, 1079,    2,    1,    0,    0,   10,    0,   38,    5],
#        [  79,   25,  266,   91,    5,    2,  269,    4,  271,   20],
#        [  32,   39,    6,  353,    2,    3,   51,    8,  409,  107],
#        [  19,    2,    5,    4,  168,    7,   63,    7,  210,  497],
#        [  71,   25,    1,   20,    3,   44,   40,    2,  586,  100],
#        [  12,   12,    3,    1,    1,    7,  895,    0,   26,    1],
#        [   0,   15,    2,   10,    5,    1,    5,  280,   39,  671],
#        [  13,   72,    3,    7,    3,   11,   12,    4,  648,  201],
#        [   5,    7,    3,    6,    1,    0,    1,   13,   18,  955]])

# %%
#Accuracy clasificador bayesiano
accuracy_score(y_test, y_pred)
# Out:
# 0.5558

# %% [markdown]
# # Maquinas de vectores de soporte
#
# Lo que hacen las maquinas de soporte de vectores es buscar separar los elementos por clase de la mejor manera posible.

# %%
from sklearn import svm

# %%
model_svm = svm.LinearSVC().fit(X_train, y_train)

y_pred = model_svm.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 961,    0,    1,    1,    1,    4,    6,    3,    2,    1],
#        [   0, 1110,    4,    3,    0,    1,    5,    1,   11,    0],
#        [   9,   10,  908,   20,   11,    6,   15,   13,   38,    2],
#        [   4,    0,   19,  919,    2,   23,    4,   12,   19,    8],
#        [   1,    4,    6,    5,  914,    0,    7,    3,    5,   37],
#        [  10,    1,    0,   38,   12,  767,   18,    8,   30,    8],
#        [   9,    4,    8,    1,    5,   19,  910,    0,    2,    0],
#        [   2,    7,   24,    7,    8,    2,    1,  944,    3,   30],
#        [   9,   12,    8,   19,   15,   33,   12,   11,  843,   12],
#        [   6,    8,    2,   16,   31,   12,    0,   27,   12,  895]])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9171

# %% [markdown]
# # Arboles de decision
#
# El arbol de decision es una estructura en forma de arbol en el cual cada nodo representa una variable o caracteristica la cual dependiendo de la regla va a la siguiente rama o no y dependiendo donde acaben hay un label resultante

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
model_tree = DecisionTreeClassifier(random_state = 1025)
model_tree.fit(X_train, y_train)

y_pred = model_tree.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 913,    0,   11,   10,    4,   10,   11,    4,   11,    6],
#        [   0, 1091,   13,    4,    2,    4,    5,    3,   12,    1],
#        [   9,    7,  889,   33,   14,   10,   14,   24,   25,    7],
#        [   7,    6,   28,  868,    6,   40,    5,    9,   22,   19],
#        [   4,    5,    4,    7,  863,    8,   14,    9,   20,   48],
#        [  12,    8,    6,   39,   10,  747,   19,    6,   29,   16],
#        [  16,    3,   10,    9,   16,   21,  855,    0,   22,    6],
#        [   3,   11,   24,   21,    8,    4,    2,  925,   10,   20],
#        [  11,    8,   32,   38,   24,   29,   13,    7,  782,   30],
#        [  15,    4,   10,   20,   41,   13,    8,   16,   22,  860]])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8793

# %%
print(plot_tree(model_tree))
# Out:
# [Text(0.5803132942887079, 0.9901960784313726, 'x[350] <= 131.5\ngini = 0.9\nsamples = 60000\nvalue = [5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851\n5949]'), Text(0.3404328977745649, 0.9705882352941176, 'x[568] <= 0.5\ngini = 0.881\nsamples = 39160\nvalue = [5433.0, 623.0, 4772.0, 1312.0, 5353.0, 3266.0, 4775.0\n5773.0, 3081.0, 4772.0]'), Text(0.46037309603163645, 0.9803921568627452, 'True  '), Text(0.18670363345891802, 0.9509803921568627, 'x[430] <= 0.5\ngini = 0.839\nsamples = 24084\nvalue = [697.0, 414.0, 904.0, 847.0, 5133.0, 1668.0, 2771.0\n5568.0, 1439.0, 4643.0]'), Text(0.09432927954020043, 0.9313725490196079, 'x[405] <= 2.5\ngini = 0.705\nsamples = 9667\nvalue = [258.0, 404.0, 565.0, 424.0, 503.0, 503.0, 315.0, 4974.0\n836.0, 885.0]'), Text(0.05509968066344454, 0.9117647058823529, 'x[484] <= 0.5\ngini = 0.475\nsamples = 6717\nvalue = [247, 71, 401, 93, 336, 92, 166, 4803, 18, 490]'), Text(0.03673851119411833, 0.8921568627450981, 'x[153] <= 0.5\ngini = 0.262\nsamples = 
# ...

# %% [markdown]
# # Conclusion
#
# En conclusion se puede ver que de los 3 modelos probados hay un claro perdedor el cual es el bayesiano debido a que tiene un accuracy de 55%, de los otros dos modelos el que tiene la mejor accuracy es el de SVM sin embargo tiene una debilidad la cual es el tiempo que se tardo en entrenar, por eso yo recomendaria el SVM si es que el tiempo de entrenamiento no es un problema, sino el arbol de desicion es la mejor opcion.
