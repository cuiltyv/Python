# %% [markdown]
# ### A01721636 Carlos Cuilty Villarreal

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
media = 0
sigma = 1

v = np.random.normal(media, sigma, 500)

# %%
plt.hist(v)
# Out:
# (array([  3.,  14.,  38.,  89., 102., 121.,  84.,  31.,  16.,   2.]),
#  array([-2.95062222, -2.35532931, -1.76003639, -1.16474348, -0.56945056,
#          0.02584235,  0.62113526,  1.21642818,  1.81172109,  2.40701401,
#          3.00230692]),
#  <BarContainer object of 10 artists>)

# %%
media = 5
sigma = 1

v1 = np.random.normal(media, sigma, 500)

media = 0
sigma = 10

v2 = np.random.normal(media, sigma, 500)

# %%
plt.hist(v1)
# Out:
# (array([  5.,  12.,  34.,  44.,  82., 105.,  96.,  69.,  36.,  17.]),
#  array([2.08319907, 2.59473983, 3.1062806 , 3.61782136, 4.12936213,
#         4.64090289, 5.15244365, 5.66398442, 6.17552518, 6.68706595,
#         7.19860671]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(v2)
# Out:
# (array([  8.,  20.,  49., 101.,  84., 104.,  68.,  44.,  18.,   4.]),
#  array([-26.77006922, -21.29748731, -15.82490541, -10.3523235 ,
#          -4.87974159,   0.59284031,   6.06542222,  11.53800413,
#          17.01058603,  22.48316794,  27.95574985]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 4. Muestra las tres graficas y comenta como vario cada una de ellas al modificar el estadistico descriptivo seleccionado
#
# ### Grafica 1. Original
#
# ### Grafica 2. Se modifico la media a 5
#
# Lo que sucedio fue que el centro de la grafica ahora se basa en el 5 no en el 0
#
# ### Grafica 3. Se modifico la varianza y se puso 10 en la deviasion estandard
#
# Lo que sucedio fue que se abrio mas la grafica en vez de tener como maximo 3 en ambos lados ahora es alrededor de 30
